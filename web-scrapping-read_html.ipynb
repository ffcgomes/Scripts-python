# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

# %%
table_NBA = pd.read_html('https://en.wikipedia.org/wiki/NBA_Finals', match='Finals appearances')
len(table_NBA)
# Out:
# 2

# %%
df=table_NBA[1]
df
# Out:
#       P                    Team   W   L    Win  \
# 0   185      Los Angeles Lakers  93  92  0.503
# 1   129          Boston Celtics  77  52  0.597
# 2    53      Philadelphia 76ers  24  29  0.453
# 3    59   Golden State Warriors  34  25  0.576
# 4    48         New York Knicks  20  28  0.417
# 5    40         Detroit Pistons  22  18  0.550
# 6    35           Chicago Bulls  24  11  0.686
# 7    34       San Antonio Spurs  23  11  0.676
# 8    35              Miami Heat  17  18  0.486
# 9    25           Atlanta Hawks  11  14  0.440
# 10   23         Houston Rockets  12  11  0.522
# 11   23   Oklahoma City Thunder  10  13  0.435
# 12   26     Cleveland Cavaliers   7  19  0.269
# 13   20      Washington Wizards   5  15  0.250
# 14   18            Phoenix Suns   6  12  0.333
# 15   17         Milwaukee Bucks  11   6  0.647
# 16   17  Portland Trail Blazers   7  10  0.412
# 17   12        Dallas Mavericks   6   6  0.500
# 18   12               Utah Jazz   4   8  0.333
# ...

# %%
table_futebol = pd.read_html('https://www.cnnbrasil.com.br/esporte/futebol/brasileirao-serie-a-2021/')
len(table_futebol)
# Out:
# 1

# %%
df=table_futebol[0]
df
# Out:
#              Classificação   p   j   v   e   d   g  gc  sg
# 0      1  Atlético-MG  CAM  84  38  26   6   6  67  34  33
# 1         2  Flamengo  FLA  71  38  21   8   9  69  36  33
# 2        3  Palmeiras  PAL  66  38  20   6  12  58  43  15
# 3        4  Fortaleza  FOR  58  38  17   7  14  44  45  -1
# 4      5  Corinthians  COR  57  38  15  12  11  40  36   4
# 5       6  Bragantino  BRG  56  38  14  14  10  55  46   9
# 6       7  Fluminense  FLU  54  38  15   9  14  38  38   0
# 7       8  América-MG  AMG  53  38  13  14  11  41  37   4
# 8      9  Atlético-GO  AGO  53  38  13  14  11  33  36  -3
# 9          10  Santos  SAN  50  38  12  14  12  35  40  -5
# 10          11  Ceará  CEA  50  38  11  17  10  39  38   1
# 11  12  Internacional  INT  48  38  12  12  14  44  42   2
# 12      13  São Paulo  SAO  48  38  11  15  12  31  39  -8
# 13   14  Athletico-PR  CAP  47  38  13   8  17  41  45  -4
# 14         15  Cuiabá  CUI  47  38  10  17  11  34  37  -3
# ...

# %%
table_futebol = pd.read_html('https://www.cbf.com.br/futebol-brasileiro/competicoes/campeonato-brasileiro-serie-a/2021')
len(table_futebol)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# D:\ArquivosDeProgramas\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1353             try:
# -> 1354                 h.request(req.get_method(), req.selector, req.data, headers,
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#
# D:\ArquivosDeProgramas\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1255         """Send a complete request to the server."""
# -> 1256         self._send_request(method, url, body, headers, encode_chunked)
#    1257
#
# D:\ArquivosDeProgramas\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1301             body = _encode(body, 'body')
# -> 1302         self.endheaders(body, encode_chunked=encode_chunked)
#    1303
#
# ...
